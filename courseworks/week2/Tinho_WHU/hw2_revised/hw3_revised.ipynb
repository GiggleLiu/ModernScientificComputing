# %%
using BenchmarkTools
using Plots
using Distributions


function simulate_brownian_motion(n::Int64)
    
    x = 0.0
    y = 0.0
    x_positions = [x]
    y_positions = [y]
    cov = [1.0 0.0; 0.0 1.0]
    

    for i in 1:n
        dx, dy = rand(MvNormal(zeros(2), cov))
        x += dx
        y += dy
        push!(x_positions, x)
        push!(y_positions, y)
    end

    return x_positions, y_positions
end

n_steps = 10000
x_positions, y_positions = simulate_brownian_motion(n_steps)

plot(x_positions, y_positions, xlabel="x", ylabel="y", legend=false,title="2D simulation of Brownian Motion")

@benchmark simulate_brownian_motion($n_steps)
# Out:
# BenchmarkTools.Trial: 1057 samples with 1 evaluation.
#  Range (min … max):  4.005 ms …   9.729 ms  ┊ GC (min … max): 0.00% … 41.58%
#  Time  (median):     4.486 ms               ┊ GC (median):    0.00%
#  Time  (mean ± σ):   4.720 ms ± 812.083 μs  ┊ GC (mean ± σ):  4.17% ±  9.49%
#
#    ▁▂▇██▇▇█▆▆▅▄▃▂▁                              ▁             ▁
#   ███████████████████▇▅▁▅▆█▅▆▁▅▄▄▆▄▁▁▄▁▁▁▁▄▄▁▆▇▇█▇▇█▇▆▆█▆▆▅▁▅ █
#   4 ms         Histogram: log(frequency) by time       7.7 ms <
#
#  Memory estimate: 3.23 MiB, allocs estimate: 40019.

# %%
plot(x_positions, y_positions, xlabel="x", ylabel="y", legend=false,title="2D simulation of Brownian Motion")
